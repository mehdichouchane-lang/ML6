# %% [markdown]
# # Part 2: Time Series Forecast with ARIMA (2 days) 📈

# %% [markdown]
# Welcome to the second part of your journey towards mastering the art of forecasting with ARIMA models. We will demystify ARIMA models, beginning with its foundational principles - autoregression, differencing, moving average. Using the same dataset as in Part 1, you will fit different models and assess their quality in order to compare them. You will also learn the different way of performing train/test splits and cross-validation in the context of time series!
#
# In this notebook, we will cover the following concepts:
# - Train / Test splitting for time series
# - Naive forecasting models
# - ARIMA and SARIMA models
# - Cross-Validation for time series

# %% [markdown]
# **Objectives**
# - Get to use few prediction models
# - Understand Cross-Validation in the context of Time Series

# %% [markdown]
# **Ressources**
#
# AR, MA, ARIMA :
#
# - https://www.youtube.com/watch?v=Mc6sBAUdDP4&list=PLjwX9KFWtvNnOc4HtsvaDf1XYG3O5bv5s&index=6
# - https://www.youtube.com/watch?v=zNLG8tsA_Go&list=PLjwX9KFWtvNnOc4HtsvaDf1XYG3O5bv5s&index=6
# - https://www.youtube.com/watch?v=dXND1OEBABI&list=PLjwX9KFWtvNnOc4HtsvaDf1XYG3O5bv5s&index=7
#
# ACF & PACF :
#
# - https://machinelearningmastery.com/gentle-introduction-autocorrelation-partial-autocorrelation/
#
# Métriques :
#
# - https://towardsdatascience.com/time-series-forecast-error-metrics-you-should-know-cc88b8c67f27
#
# Cross-validation :
#
# - https://stats.stackexchange.com/questions/14099/using-k-fold-cross-validation-for-time-series-model-selection
# - https://robjhyndman.com/hyndsight/tscv/
#
# Forecasting: Principles and Practice livre (Rob Hyndman) :
#
# - https://otexts.com/fpp2/
# - https://otexts.com/fpp2/non-seasonal-arima.html
# - https://otexts.com/fpp2/transformations.html
# - https://otexts.com/fpp2/seasonal-arima.html
#
# Documentation de Pmdarima:
#
# - http://alkaline-ml.com/pmdarima/

# %% [markdown]
# **Required librairies**
# - [ ] numpy
# - [ ] pandas
# - [ ] matplotlib
# - [ ] seaborn
# - [ ] pmdarima
# - [ ] sktime

# %%
# Import required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pmdarima as pm
import sktime as sk

# %% [markdown]
# # A bit of theory, again 😁

# %% [markdown]
# The ARMA (AutoRegressive Moving Average) model is suitable for predicting any time series whose value $Y$ at time $t$ can be explained by previous values and previous perturbations (noise).
#
# Before specifying what a dataset is according to the ARIMA model, let's specify a dataset according to the conditions :
#
# - **Autoregressive**: the model predicts the variable $Y$ at time $t$, denoted $Y_t$, from previous values of $Y$ according to a linear regression model, i.e. $Y_{t-1}, Y_{t-2}, ..., Y_0$. Let $p$ denote the number of components used to predict $Y_t$, with
#
# > $Y_t = \sum_{i=1}^p \varphi_i\,Y_{t-i} + \varepsilon_t + c$, with $\varepsilon_t$ a perturbation, and c a constant.
#
# - **Moving average**: a model where the data are the result of the moving average of order $q$. The value $Y_t$ can be expressed using the perturbation at time $t$ and its previous values:
#
# > $Y_t = \mu + \varepsilon_t + \sum_{1}^{q}\theta_q\varepsilon_{t-q}$, with $\mu$ a constant.
#
# Any ARMA model is the combination of the *AR* and *MA* conditions, i.e. it is autoregressive and its noise follows a moving average. Let :
#
# > $Y_t = c + \sum_{i=1}^p \varphi_i\,Y_{t-i} + \varepsilon_t + \sum_{1}^{q}\theta_q\varepsilon_{t_q}$
#
# or :
#
# > $Y_t - \sum_{i=1}^p \varphi_i Y_{t-i} = \varepsilon_t + \sum_{i=1}^q \theta_i \varepsilon_{t-i}$ with $\varepsilon_t$ the error of the autoregressive model at time $t$.
#
# The model is optimized using the least-squares method.
#
# An ARMA model is suitable for stationary data sets, i.e. with a fixed mean and standard deviation over time. Such data are rarely observed. Many time series datasets show trends in the mean or seasonal patterns. To do this, the problem must first be stationarized. As we saw before, this can be done by differencing the data, apply a model, and then performing the reverse operation: **integration**. An **ARIMA** model is said to be :
#
# - **integrated**: when the data set can be corrected by running the model on $Y'_t = Y_t - Y_{t-1}$ for a correction of order 1 (d=1), or $Y''_t = Y_t - Y_{t-1} - Y_{t-2}$ for a correction of order 2 (d=2), etc...  We note $d$ the order of *correction by integration* to suppress polynomial tendencies of order $d$, with:
#
# > $Ycorr_t = Y_t - \sum_{1}^{d} Y_{t-d}$
#
#
# ARIMA models are often denoted: ARIMA(p, d, q), or **ARIMA(2, 1, 1)** means :
# - an autoregressive model of order 2,
# - on data integrated 1 times,
# - with a moving average of order 1.

# %% [markdown]
# # 1. Train / Test Splitting

# %% [markdown]
# Because the temporal order is important in time series, we cannot perform a random train/test split. Rather, we can use the most recent data (e.g. the last year) as the test set!

# %% [markdown]
# **TODO**
# - Explain why train/test splitting can be a challenge for time series
# - Write a function to split the dataset into a train and test set
# - Use the function to split the airline passengers dataset, keeping the last twelve months as a test set
# - Plot the train and test set in different colors

# %%
from sktime.datasets import load_airline

# Load dataset
airline = load_airline()

# Clean & Adjust the data
airline = airline.dropna()
airline_adj = airline / airline.index.days_in_month

# %%
airline
# Out:
# Period
# 1949-01    112.0
# 1949-02    118.0
# 1949-03    132.0
# 1949-04    129.0
# 1949-05    121.0
#            ...
# 1960-08    606.0
# 1960-09    508.0
# 1960-10    461.0
# 1960-11    390.0
# 1960-12    432.0
# Freq: M, Name: Number of airline passengers, Length: 144, dtype: float64

# %%
import numpy as np
import pandas as pd

def ts_train_test_split(data, split_date):
    '''
    Split time series into training and test data.
    
    Parameters:
    -------
    data : pd.Series or pd.DataFrame
        Time series data with an index (numeric, datetime, or period).
    split_date : str or numeric
        The date/position on which to split the series.
    
    Returns:
    --------
    (train, test) : tuple of pandas.Series/DataFrame
    '''
    
    idx = data.index

    # Case 1: numeric index
    if np.issubdtype(getattr(idx, "dtype", np.dtype("O")), np.number) or isinstance(idx, pd.Index):
        pos_split = int(split_date)
        pos_split=np.argwhere(idx>pos_split)[0][0]
        train = data.iloc[:pos_split]
        test = data.iloc[pos_split:]

    # Case 2: DatetimeIndex
    elif isinstance(idx, pd.DatetimeIndex):
        split_date = pd.to_datetime(split_date)
        if split_date in idx:
            pos_split = np.argwhere(idx == split_date)[0][0]
        else:
            pos_split = np.argwhere(idx > split_date)[0][0]
        train = data.iloc[:pos_split]
        test = data.iloc[pos_split:]

    # Case 3: PeriodIndex
    elif isinstance(idx, pd.PeriodIndex):
        split_period = pd.Period(split_date)
        if split_period in idx:
            pos_split = np.argwhere(idx == split_period)[0][0]
        else:
            pos_split = np.argwhere(idx > split_period)[0][0]
        train = data.iloc[:pos_split]
        test = data.iloc[pos_split:]

    else:
        raise TypeError(f"Unsupported index type: {type(idx)}")

    return train, test

# %%
type(airline_adj.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
from sktime.utils.plotting import plot_series

# Hold back the last three years as a TEST set
train,test = ts_train_test_split(airline_adj, '1958-01')

# Check train and test sizes are what we expect
print('Train size:',train.shape)

print('Test size:',test.shape)
# Plot the series
plt.figure()
plt.plot(train.index.to_timestamp(),train.values,'-b',label='train')
plt.plot(test,'-r',label='test')
plt.legend()
plt.show()
# Out:
# coucou
# Train size: (108,)
# Test size: (36,)

# %% [markdown]
# # 2. Naive Forecast

# %% [markdown]
# We need a baseline (as always!) to know if our more complex models are any use! Given the strong seasonal component that was confirmed by the seasonal decomposition we made earlier, it may be a good idea to use a **seasonal naive** forecasting method. This model takes the value from the same period in the previous season (in this case the same month last year). This is part of the Carry-Forward-Previous-Values' family of **naive** forecasting methods. In general, if we have data with period $k$ are at time $t$ and we are predicting time $Y_{t+1}$ then we simply carry forward the value from $Y_{t+1-k}$. In other words, we have yearly data so we just take the value from the same month last year.

# %%
from sktime.forecasting.naive import NaiveForecaster
from sktime.forecasting.base import ForecastingHorizon
from sktime.utils.plotting import plot_series

HORIZON = 12  # We plan to make forecasts for the following 12 months
PERIOD = 12  # Expected period of seasonality

# Define the length of time into the future for which forecasts are to be prepared
fh = ForecastingHorizon(test.index, is_relative=False)
fh_12 = fh[:HORIZON]

# %% [markdown]
# ### 2.1 Fit a Naive Forecaster

# %% [markdown]
# **TODO**
# - Fit a Naive and Seasonal Naive forecaster to the train data, and show the predictions along with the test data.
# - Plot the residuals using Seaborn's `displot()`, `regplot()` and `residplot()` functions.

# %%
# Your code for the Naive Forecaster
naive_forecast = NaiveForecaster(strategy='drift',window_length=PERIOD)
naive_forecast.fit(train)
pred = naive_forecast.predict(fh_12)
fig,ax = plot_series(train)
plot_series(test[:HORIZON],ax=ax,colors='gray')
plot_series(pred,ax=ax,colors='r')
ax.set_ylabel('Passengers')
ax.legend(['Raw Values','Test Values','Naive  Predictions'])
ax.set_title('12 Months Naive  Prediction')
plt.show()

# %%
# Your code for the Seasonal Naive Forecaster
naive_forecast = NaiveForecaster(strategy='last',sp=PERIOD)
naive_forecast.fit(train)
pred_season = naive_forecast.predict(fh_12)
fig,ax = plot_series(train)
plot_series(test[:HORIZON],ax=ax,colors='gray')

plot_series(pred_season,ax=ax,colors='r')
ax.set_ylabel('Passengers')
ax.legend(['Raw Values','Test Values','Naive Seasonal Predictions'])
ax.set_title('12 Months Naive Seasonal Prediction')
plt.show()

# %% [markdown]
# Plotting the **residuals** can give us information about how the model is performing and the errors it is making.  Sometimes there are reffered to as **in sample** diagnostics. This just means we are looking at diagnostics of data which has been used to fit the model.

# %%
fig, axes = plt.subplots(2, 1, sharex=True, sharey=True, figsize=(12, 8))
sns.residplot(x=np.array(range(HORIZON)), y = test.values[:HORIZON],y_partial= pred.values[:HORIZON],ax=axes[0])
axes[0].set_title('Naive Prediction Residuals')
sns.residplot(x=np.array(range(HORIZON)), y = test.values[:HORIZON],y_partial= pred_season.values[:HORIZON],ax=axes[1])
axes[1].set_title('Naive Seasonal Prediction Residuals')
temp = axes[1].get_xticks()
if min(temp)<0:
    temp = temp - min(temp)
year_month = test.index[:HORIZON].to_timestamp().to_period('M').astype(str)
lab = ['garbage']
# for t in temp:
#     if t<len(string):
#         lab.append(string[int(t)])
#     else:
#         lab.append('garbage')
# axes[1].set_xticklabels(lab)
plt.show()

# %% [markdown]
# ### 2.2 Error Metrics

# %% [markdown]
# You've probably already worked with the Mean Squared Error (MSE). Let's have a look at different metrics.
#
# RMSE and MAE are called 'scale dependent' measures as the units and magnitude are specific to the problem and context.  An alternative approach is to use a scale invariant measure such as the **mean absolute percentage error (MAPE)**
#
# The percentage error is given by $p_t = 100e_t/y_t$ where $e_t$ is the error in predicting $y_t$.  Therefore, MAPE = $mean(|p_t|)$. A limitation of MAPE is that it is inflated when the denominator is small relative to the absolute forecast error (such in the case of outliers or extreme unexpected events). It also penalises negative errors more than positive errors.  A consequence of this property is that MAPE can lead to selecting a model that tends to under forecast.  The two following examples illustrate the issue. $$APE_{1} = \left| \frac{y_t - \hat{y_t}}{y_t} \right|= \left| \frac{150 - 100}{150} \right| = \frac{50}{150} = 33.33\%$$
#
# $$APE_{2} = \left| \frac{100 - 150}{100} \right| = \frac{50}{100} = 50\%$$

# %% [markdown]
# **TODO**
# - Write a function to compute the MAPE
# - Calculate the in-sample RMSE and MAPE for the last twelve months

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    '''
    MAPE

    Parameters:
    --------
    y_true -- np.array actual observations from time series
    y_pred -- the predictions to evaluate

    Returns:
    -------
    float, scalar value representing the MAPE (0-100)
    '''    
    return 100*np.mean(abs(y_true-y_pred)/y_true)

# %%
# Your code calculating the RMSE and MAPE for the Naive and Seasonal Naive models
from sklearn.metrics import root_mean_squared_error
mape_naive = mean_absolute_percentage_error(test.values[:HORIZON],pred.values)
mape_season = mean_absolute_percentage_error(test.values[:HORIZON],pred_season.values)
print(f'The MAPE for the Naive and Naive Seasonal Models are respectively {round(mape_naive,2)}%, and {round(mape_season,2)}%')
print(f'The RMSE for the Naive and Naive Seasonal Models are respectively {round(root_mean_squared_error(test.values[:HORIZON],pred.values),2)}, and {round(root_mean_squared_error(test.values[:HORIZON],pred_season.values),2)}')
# Out:
# The MAPE for the Naive and Naive Seasonal Models are respectively 11.28%, and 3.14%
# The RMSE for the Naive and Naive Seasonal Models are respectively 2.3, and 0.55

# %% [markdown]
# # 3. ARIMA Forecast

# %% [markdown]
# Let's try an ARIMA model at last. Using a classical statsitical approach you would select the order of model which produces a model with acceptable residual plots (remember the first part of linear regression module?). Selecting the best model can also be done automatically using packages which do it for you! Wohoo! 🎉
#
# The `pmdarima` package is an excellent forecasting library for building ARIMA models.  I recommend it over the options available in the core `statsmodels` package.  It is easier to use and offers an `auto_arima()` function that iteratively searches for a model that minimises the **Akaike Information Criterion (AIC)**
#
# * ${\displaystyle \mathrm {AIC} \,=\,2k-2\ln({\hat {L}})}$
#
# where $k$ = number of parameters in the model and $\hat{L}$ is the maximum value of the likelihood function for the model.  A likelihood function measures the 'goodness' of fit of a model to data given a set of parameters.
#
# This looks very complicated at first, but all we need to remember is that the models we are working with are very flexible. This means that we can easily create complex models that overfit. Recall that overfitting is when a model will predict the training data exceptionally well, but will perform poorly on out of sample data.  The form of AIC means that it rewards models that fit the training data well, but also penalises models with high $k$ (complicated models with lots of parameters).  That means that AIC will prefer simpler models - in turn reducing overfitting.  That's a great formula for automatically selecting a good ARIMA forecasting model.
#
# Even though modern applications tend to opt for the automatic approach for selecting the ARIMA parameters, we will have a go a trying and comparing how we perform with manual selection. As we discussed above, to train an ARIMA($p$,$d$,$q$) model we need to specify three parameters: $p$ (*AR*), $d$ (*I*) and $q$ (*MA*):
# - To determine $p$, we look at the *direct* correlations, i.e. the *PACF*, and search for the lag $i$ such that $PACF_i \approx 0$
# - To determine $q$, we look at the *full* correlations, i.e. the *ACF*, and search for the lag $i$ such that $ACF_i \approx 0$
#
# Sometimes, we cannot apply directly these guidelines, and we must rely on a more detailed analysis or a grid search to determine the best $p,q$ for the problem at hand.

# %% [markdown]
# ### Load the dataset & transform it

# %% [markdown]
# ARIMA models can take into account an increasing mean over time, but not the variance. Thus, a log transformation is enough for our purposes!

# %%
# Reload dataset from pmdarima
from pmdarima.datasets import load_airpassengers
from pmdarima.utils import acf, pacf
from pmdarima import ARIMA
import pandas as pd
# Load dataset
START_DATE = '1949-01-01'
airline = load_airpassengers(as_series=True)

# There's no DateTimeIndex from the bundled dataset. So let's add one.
airline.index = pd.date_range(START_DATE, periods=len(airline), freq='MS')

# Clean & Adjust data
airline_adj = airline / airline.index.days_in_month

# Train / Test split
train, test = ts_train_test_split(airline_adj, '1960-01-01')

# Apply log transformation
train_log = np.log(train).dropna()
test_log = np.log(test).dropna()

# %% [markdown]
# ### 3.1 Estimate $p$, $d$ and $q$

# %% [markdown]
# **TODO**
# - Based on the analysis done on the previous notebook, what would be a plausible value for $d$ ?
# - Plot the ACF and PACF and determine some plausible values for $p$ and $q$.
# - Fit the ARIMA model and show the diagnostics using the `plot_diagnostics()` of pmdarima. Describe the different plots. How do you interpret these results ?

# %%
# Your code for the ACF & PACF plots
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Plot the ACF and PACF
fig, axes = plt.subplots(2, 1, sharex=True,figsize=(10, 8))
ax = axes[0]
plot_acf(train_log.diff().dropna(), lags=50, ax=ax) # Plot first 20 lags
ax.plot([12,12],[-1,1],'-k',linewidth=2)
ax.set_xlabel("Lag")
ax.set_ylabel("Autocorrelation")
ax.set_title("Autocorrelation Function (ACF)")
ax = axes[1]
plot_pacf(train_log.diff().dropna(), lags=50, ax=ax) # Plot first 20 lags
ax.set_xlabel("Lag")
ax.set_ylabel("Partial Autocorrelation")
ax.plot([12,12],[-1,1],'-k',linewidth=2)

ax.set_title("Partial Autocorrelation Function (PACF)")
plt.show() # Display the plotplot_pacf(airline_adj)

# %%
# Your code for the ARIMA model
d  = 1 
p = 12
q = 12
arm = ARIMA([p,d,q])
arm.fit(train_log)
# Out:
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(order=[12, 1, 12])

# %%
fig = plt.figure(figsize=[12,8])
arm.plot_diagnostics(fig=fig)

# %% [markdown]
# **TODO**
# - Make a figure showing the train set, the test set, the predictions from ARIMA and the confidence intervals
# - Make a second figure showing the predictions for the next 100 periods
# - Calculate the RMSE and the MAPE on the test set

# %%
# Your code showing train, test, predictions and confidence interval

pred_arm,conf_int = arm.predict(len(test_log),return_conf_int=True)
fig,ax = plot_series(np.exp(train_log),colors=[(.4,.4,.4)])
plot_series(np.exp(test_log),ax=ax,colors=[(.4,.4,.9)])

plot_series(np.exp(pred_arm),ax=ax,colors='r')
ax.set_ylabel('Passengers')
ax.set_title('ARIMA Prediction')
conf_int = np.exp(conf_int)
ax.fill_between(test_log.index, conf_int[:,0], conf_int[:,1],alpha=.25,color=[.2,.7,.7])
ax.legend(['Raw Values','Test Values','ARIMA Predictions','95% Confidence Interval'])

plt.show()
# Out:
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# Your code for showing the predictions for 100 periods

pred_arm100,conf_int100 = arm.predict(100,return_conf_int=True)
fig,ax = plot_series(np.exp(train_log),colors=[(.4,.4,.4)])
# plot_series(np.exp(test_log),ax=ax,colors=[(.4,.4,.9)])
conf_int100 = np.exp(conf_int100)

plot_series(np.exp(pred_arm100),ax=ax,colors='r')
ax.set_ylabel('Passengers')
ax.fill_between(pred_arm100.index, conf_int100[:,0], conf_int100[:,1],alpha=.25,color=[.2,.7,.7])
ax.legend(['Raw Values','ARIMA Predictions','95% Confidence Interval'])
ax.set_title('ARIMA Prediction for 100 Peridos')
plt.show()
# Out:
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from sklearn.metrics import mean_squared_error

# Your code calculating the RMSE and MAPE
mape_ = mean_absolute_percentage_error(np.exp(test_log.values),np.exp(pred_arm.values))
print(f'The MAPE and RMSE for the ARIMA model are respectively {round(mape_,2)}%, and {round(root_mean_squared_error(np.exp(test_log.values),np.exp(pred_arm.values)),2)}')
# Out:
# The MAPE and RMSE for the ARIMA model are respectively 3.8%, and 0.67

# %% [markdown]
# **Conclusions**
# - What are your conclusions ?
# - What do you think about the error?

# %% [markdown]
# ### 3.2 Seasonal ARIMA

# %% [markdown]
# As we have seen previously, ARMA models are well suited for stationary data. They may even works for data presenting seasonality, however seasonality is not clearly expressed. If data shows seasonality less simple as for the airport's data, calculation complexity and time can explode.
#
# **Example** : Data compiling sun activity with a seasonality of 12 +/-1 year would require a minimum of $p=12*12$ to comprehend seasonality of the problem!
#
# <span style="color: blue">Here comes SARIMA: Seasonal-ARIMA!</span>
#
# The Seasonal ARIMA model, also known as SARIMA, is an extension of the basic ARIMA model that takes into account seasonality in the data. In a SARIMA model, we introduce additional seasonal components to the ARIMA model. The seasonal components mirror the ARIMA components but are applied to the seasonal patterns in the data. So, the SARIMA model has six additional parameters:
#
# - Seasonal Autoregressive (SAR) component: This is similar to the AR component but for the seasonal patterns. It represents the relationship between the current value of the time series and its past values at the seasonal frequency.
#
# - Seasonal Integrated (SI) component: This is similar to the I component but for the seasonal patterns. It involves differencing the time series at the seasonal frequency to achieve seasonality stationarity.
#
# - Seasonal Moving Average (SMA) component: This is similar to the MA component but for the seasonal patterns. It models the relationship between the current value of the time series and past forecast errors at the seasonal frequency.
#
# The seasonal frequency $s$ refers to the number of time periods that make up one seasonal cycle, and must also be provided to a SARIMA model. For example, if the time series exhibits a yearly seasonality, the seasonal frequency is 12 (assuming monthly data).

# %% [markdown]
# **TODO**
# - Using a seasonal decomposition of the dataset, separate it into trend, seasonality and residual parts.
# - Plot the moving mean and std of the trend and seasonal parts of the data.
# - What can you conclude about stationarity of seasonal data? Can you then define $D$ and the seasonal frequency $s$ ?
# - Does intra-seasonal data show specific seasonality ? What is $d$ (0, 1, or 2) ?
# - Use the same procedure applied previously to a build a SARIMA model and evaluate its performance.

# %%
def moving_mean(x, n):
    return x.rolling(n).mean()

def moving_std(x, n):
    return x.rolling(n).std()

# %%
# Decompose the data into a trend and seasonal part
from statsmodels.tsa.seasonal import seasonal_decompose
multModel = seasonal_decompose(train_log,model='multiplicative',extrapolate_trend='freq')

# %%
# ACF & PACF plots
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
fig, axes = plt.subplots(2, 1, sharex=True,figsize=(10, 8))
ax = axes[0]
plot_acf(multModel.seasonal, lags=30, ax=ax) # Plot first 20 lags
ax.plot([12,12],[-1,1],'-k',linewidth=2)
ax.set_xlabel("Lag")
ax.set_ylabel("Autocorrelation")
ax.set_title("Autocorrelation Function (ACF)")
ax = axes[1]
plot_pacf(multModel.seasonal, lags=30, ax=ax) # Plot first 20 lags
ax.set_xlabel("Lag")
ax.set_ylabel("Partial Autocorrelation")
ax.plot([12,12],[-1,1],'-k',linewidth=2)

ax.set_title("Partial Autocorrelation Function (PACF)")
plt.show() # Display the plotplot_pacf(airline_adj)

# %%
# Fit the SARIMA model

# Your code for the ARIMA model
d  =1 
p = 2
q = 11
# Your code for the ARIMA model
D  =1 
P = 3
Q = 12
s=12
sarm = ARIMA(order=[p,d,q],seasonal_order=[D,P,Q,s])
sarm.fit(train_log)
# Out:
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(order=[2, 1, 11], seasonal_order=[1, 3, 12, 12])

# %%
# Show train, test, predictions and confidence interval

# Your code showing train, test, predictions and confidence interval

pred_sarm,conf_int = sarm.predict(len(test_log),return_conf_int=True)
fig,ax = plot_series(np.exp(train_log),colors=[(.4,.4,.4)])
plot_series(np.exp(test_log),ax=ax,colors=[(.4,.4,.9)])

plot_series(np.exp(pred_sarm),ax=ax,colors='r')
ax.set_ylabel('Passengers')
ax.set_title('SARIMA Prediction')
conf_int = np.exp(conf_int)
ax.fill_between(test_log.index, conf_int[:,0], conf_int[:,1],alpha=.25,color=[.2,.7,.7])
ax.legend(['Raw Values','Test Values','ARIMA Predictions','95% Confidence Interval'])

plt.show()
# Out:
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# Calculate the RMSE and the MAPE
from sklearn.metrics import mean_squared_error
mape_ = mean_absolute_percentage_error(np.exp(test_log.values),np.exp(pred_sarm.values))

print(f'The MAPE and RMSE for the SARIMA model are respectively {round(mape_,2)}%, and {round(root_mean_squared_error(np.exp(test_log.values),np.exp(pred_sarm.values)),2)}')
# Out:
# The MAPE and RMSE for the SARIMA model are respectively 10.3%, and 1.83

# %% [markdown]
# **Conclusions**
# - What are your conclusions with respect to the previous ARIMA model ?

# %% [markdown]
# ### 3.3 Auto-Arima  🎉

# %% [markdown]
# Auto ARIMA is an automated time series forecasting method that automatically selects the best combination of ARIMA model parameters ($p$, $d$, $q$) based on the data's characteristics. It uses algorithms to iteratively search and evaluate different models to find the most suitable one, saving users from manually tuning the parameters. Auto ARIMA is a powerful tool for efficiently forecasting time series data, especially when dealing with large datasets or when users have limited knowledge of time series modeling.

# %% [markdown]
# **TODO**
# - Fit an `auto_arima` model and plot the diagnostics.
# - How does it compare to the best model you found previously ?

# %%
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error


auto_arima = auto_arima(train_log,seasonal=True,max_d=1,start_P=1,start_Q=1,m=12,n_jobs=-1)
# Out:
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\_validation.py:76: UserWarning: stepwise model cannot be fit in parallel (n_jobs=1). Falling back to stepwise parameter search.
#   warnings.warn('stepwise model cannot be fit in parallel (n_jobs=%i). '
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 5
#       1 from pmdarima.arima import auto_arima
#       2 from sklearn.metrics import mean_squared_error
# ----> 5 auto_arim = auto_arima(train_log,seasonal=True,max_d=1,start_P=1,start_Q=1,m=12,n_jobs=-1)
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\auto.py:701, in auto_arima(y, X, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     669     # init the stepwise model wrapper
#     670     search = solvers._StepwiseFitWrapper(
#     671         y,
#     672         X=X,
#    (...)    698         **sarimax_kwargs,
#     699     )
# --> 701 sorted_res = search.solve()
#     702 return _return_wrapper(sorted_res, return_valid_fits, start, trace)
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\_auto_solvers.py:307, in _StepwiseFitWrapper.solve(self)
#     305 _q = 1 if max_q > 0 else 0
#     306 _Q = 1 if (m > 1 and max_Q > 0) else 0
# --> 307 if self._do_fit((0, d, _q), (0, D, _Q, m)):
#     308     p = P = 0
#     309     Q = _Q
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\_auto_solvers.py:235, in _StepwiseFitWrapper._do_fit(self, order, seasonal_order, constant)
#     230 if (order, seasonal_order, constant) not in self.results_dict:
#     231
#     232     # increment the number of fits
#     233     self.k += 1
# --> 235     fit, fit_time, new_ic = self._fit_arima(
#     236         order=order,
#     237         seasonal_order=seasonal_order,
#     238         with_intercept=constant)
#     240     # use the orders as a key to be hashed for
#     241     # the dictionary (pointing to fit)
#     242     self.results_dict[(order, seasonal_order, constant)] = fit
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\_auto_solvers.py:508, in _fit_candidate_model(y, X, order, seasonal_order, start_params, trend, method, maxiter, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, information_criterion, **kwargs)
#     500 fit = ARIMA(order=order, seasonal_order=seasonal_order,
#     501             start_params=start_params, trend=trend, method=method,
#     502             maxiter=maxiter, suppress_warnings=suppress_warnings,
#     503             out_of_sample_size=out_of_sample_size, scoring=scoring,
#     504             scoring_args=scoring_args,
#     505             with_intercept=with_intercept, **kwargs)
#     507 try:
# --> 508     fit.fit(y, X=X, **fit_params)
#     510 # for non-stationarity errors or singular matrices, return None
#     511 except (LinAlgError, ValueError) as v:
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\arima.py:603, in ARIMA.fit(self, y, X, **fit_args)
#     600         X = safe_indexing(X, slice(0, n_exog - cv))
#     602 # Internal call
# --> 603 self._fit(y, X, **fit_args)
#     605 # now make a forecast if we're validating to compute the
#     606 # out-of-sample score
#     607 if cv_samples is not None:
#     608     # get the predictions (use self.predict, which calls forecast
#     609     # from statsmodels internally)
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\arima.py:524, in ARIMA._fit(self, y, X, **fit_args)
#     522     with warnings.catch_warnings(record=False):
#     523         warnings.simplefilter('ignore')
# --> 524         fit, self.arima_res_ = _fit_wrapper()
#     525 else:
#     526     fit, self.arima_res_ = _fit_wrapper()
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\arima.py:510, in ARIMA._fit.<locals>._fit_wrapper()
#     507 _maxiter = fit_args.pop("maxiter", _maxiter)
#     509 disp = fit_args.pop("disp", 0)
# --> 510 fitted = arima.fit(
#     511     start_params=start_params,
#     512     method=method,
#     513     maxiter=_maxiter,
#     514     disp=disp,
#     515     **fit_args,
#     516 )
#     518 return arima, fitted
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:729, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     727 else:
#     728     func = self.smooth
# --> 729 res = func(mlefit.params, transformed=False, includes_fixed=False,
#     730            cov_type=cov_type, cov_kwds=cov_kwds)
#     732 res.mlefit = mlefit
#     733 res.mle_retvals = mlefit.mle_retvals
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:890, in MLEModel.smooth(self, params, transformed, includes_fixed, complex_step, cov_type, cov_kwds, return_ssm, results_class, results_wrapper_class, **kwargs)
#     887 result = self.ssm.smooth(complex_step=complex_step, **kwargs)
#     889 # Wrap in a results object
# --> 890 return self._wrap_results(params, result, return_ssm, cov_type,
#     891                           cov_kwds, results_class,
#     892                           results_wrapper_class)
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:789, in MLEModel._wrap_results(self, params, result, return_raw, cov_type, cov_kwds, results_class, wrapper_class)
#     786     if wrapper_class is None:
#     787         wrapper_class = self._res_classes['fit'][1]
# --> 789     res = results_class(self, params, result, **result_kwargs)
#     790     result = wrapper_class(res)
#     791 return result
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1809, in SARIMAXResults.__init__(self, model, params, filter_results, cov_type, **kwargs)
#    1807 def __init__(self, model, params, filter_results, cov_type=None,
#    1808              **kwargs):
# -> 1809     super().__init__(model, params, filter_results, cov_type, **kwargs)
#    1811     self.df_resid = np.inf  # attribute required for wald tests
#    1813     # Save _init_kwds
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:2374, in MLEResults.__init__(self, model, params, results, cov_type, cov_kwds, **kwargs)
#    2372 try:
#    2373     self._rank = None
# -> 2374     self._get_robustcov_results(cov_type=cov_type, use_self=True,
#    2375                                 **cov_kwds)
#    2376 except np.linalg.LinAlgError:
#    2377     self._rank = 0
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:2604, in MLEResults._get_robustcov_results(self, cov_type, **kwargs)
#    2601     res.cov_kwds['description'] = descriptions['OIM'].format(
#    2602                                         approx_type=approx_type_str)
#    2603 elif self.cov_type == 'opg':
# -> 2604     res.cov_params_default = res.cov_params_opg
#    2605     res.cov_kwds['description'] = descriptions['OPG'].format(
#    2606                                         approx_type=approx_type_str)
#    2607 elif self.cov_type == 'robust' or self.cov_type == 'robust_oim':
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:2734, in MLEResults.cov_params_opg(self)
#    2728 @cache_readonly
#    2729 def cov_params_opg(self):
#    2730     """
#    2731     (array) The variance / covariance matrix. Computed using the outer
#    2732     product of gradients method.
#    2733     """
# -> 2734     return self._cov_params_opg(self._cov_approx_complex_step,
#    2735                                 self._cov_approx_centered)
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:2701, in MLEResults._cov_params_opg(self, approx_complex_step, approx_centered)
#    2700 def _cov_params_opg(self, approx_complex_step=True, approx_centered=False):
# -> 2701     evaluated_hessian = self.nobs_effective * self.model._hessian_opg(
#    2702         self.params, transformed=True, includes_fixed=True,
#    2703         approx_complex_step=approx_complex_step,
#    2704         approx_centered=approx_centered)
#    2706     no_free_params = (self._free_params_index is not None and
#    2707                       len(self._free_params_index) == 0)
#    2709     if no_free_params:
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:1543, in MLEModel._hessian_opg(self, params, **kwargs)
#    1538 def _hessian_opg(self, params, **kwargs):
#    1539     """
#    1540     Hessian matrix computed using the outer product of gradients
#    1541     information matrix
#    1542     """
# -> 1543     return -self.opg_information_matrix(params, **kwargs)
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:1230, in MLEModel.opg_information_matrix(self, params, transformed, includes_fixed, approx_complex_step, **kwargs)
#    1225 if not transformed and approx_complex_step:
#    1226     raise ValueError("Cannot use complex-step approximations to"
#    1227                      " calculate the observed_information_matrix"
#    1228                      " with untransformed parameters.")
# -> 1230 score_obs = self.score_obs(params, transformed=transformed,
#    1231                            includes_fixed=includes_fixed,
#    1232                            approx_complex_step=approx_complex_step,
#    1233                            **kwargs).transpose()
#    1234 return (
#    1235     np.inner(score_obs, score_obs) /
#    1236     (self.nobs - self.ssm.loglikelihood_burn)
#    1237 )
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:1449, in MLEModel.score_obs(self, params, method, transformed, includes_fixed, approx_complex_step, approx_centered, **kwargs)
#    1447     epsilon = _get_epsilon(params, 2., None, len(params))
#    1448     kwargs['complex_step'] = True
# -> 1449     score = approx_fprime_cs(params, self.loglikeobs, epsilon=epsilon,
#    1450                              kwargs=kwargs)
#    1451 elif method == 'approx':
#    1452     score = approx_fprime(params, self.loglikeobs, kwargs=kwargs,
#    1453                           centered=approx_centered)
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tools\numdiff.py:251, in approx_fprime_cs(x, f, epsilon, args, kwargs)
#     249 increments = np.identity(n) * 1j * epsilon
#     250 # TODO: see if this can be vectorized, but usually dim is small
# --> 251 partials = [f(x+ih, *args, **kwargs).imag / epsilon[i]
#     252             for i, ih in enumerate(increments)]
#     254 return np.array(partials).T
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tools\numdiff.py:251, in <listcomp>(.0)
#     249 increments = np.identity(n) * 1j * epsilon
#     250 # TODO: see if this can be vectorized, but usually dim is small
# --> 251 partials = [f(x+ih, *args, **kwargs).imag / epsilon[i]
#     252             for i, ih in enumerate(increments)]
#     254 return np.array(partials).T
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:989, in MLEModel.loglikeobs(self, params, transformed, includes_fixed, complex_step, **kwargs)
#     984     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     986 self.update(params, transformed=True, includes_fixed=True,
#     987             complex_step=complex_step)
# --> 989 return self.ssm.loglikeobs(complex_step=complex_step, **kwargs)
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:1068, in KalmanFilter.loglikeobs(self, **kwargs)
#    1064 else:
#    1065     kwargs.setdefault(
#    1066         'conserve_memory',
#    1067         MEMORY_CONSERVE ^ (MEMORY_NO_FORECAST | MEMORY_NO_LIKELIHOOD))
# -> 1068 kfilter = self._filter(**kwargs)
#    1069 llf_obs = np.array(kfilter.loglikelihood, copy=True)
#    1070 loglikelihood_burn = kwargs.get('loglikelihood_burn',
#    1071                                 self.loglikelihood_burn)
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:913, in KalmanFilter._filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     907 def _filter(self, filter_method=None, inversion_method=None,
#     908             stability_method=None, conserve_memory=None,
#     909             filter_timing=None, tolerance=None, loglikelihood_burn=None,
#     910             complex_step=False):
#     911     # Initialize the filter
#     912     prefix, dtype, create_filter, create_statespace = (
# --> 913         self._initialize_filter(
#     914             filter_method, inversion_method, stability_method,
#     915             conserve_memory, filter_timing, tolerance, loglikelihood_burn
#     916         )
#     917     )
#     918     kfilter = self._kalman_filters[prefix]
#     920     # Initialize the state
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:480, in KalmanFilter._initialize_filter(self, filter_method, inversion_method, stability_method, conserve_memory, tolerance, filter_timing, loglikelihood_burn)
#     476     raise RuntimeError('Must bind a dataset to the model before'
#     477                        ' filtering or smoothing.')
#     479 # Initialize the representation matrices
# --> 480 prefix, dtype, create_statespace = self._initialize_representation()
#     482 # Determine if we need to (re-)create the filter
#     483 # (definitely need to recreate if we recreated the _statespace object)
#     484 create_filter = create_statespace or prefix not in self._kalman_filters
#
# File c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\representation.py:1003, in Representation._initialize_representation(self, prefix)
#    1001     pass
#    1002 else:
# -> 1003     new = getattr(self, '_' + matrix).astype(dtype)
#    1004     if existing.shape == new.shape:
#    1005         existing[:] = new[:]
#
# KeyboardInterrupt:

# %%
fig = plt.figure(figsize=[12,8])
auto_arima.plot_diagnostics(fig=fig)

# %%
pred_auto_arima
# Out:
# 1960-01-01    2.610078
# 1960-02-01    2.660588
# 1960-03-01    2.719446
# 1960-04-01    2.726744
# 1960-05-01    2.736316
# 1960-06-01    2.914583
# 1960-07-01    3.011731
# 1960-08-01    3.025527
# 1960-09-01    2.878397
# 1960-10-01    2.715637
# 1960-11-01    2.620710
# 1960-12-01    2.694409
# Freq: MS, dtype: float64

# %%
pred_auto_arima,conf_int = auto_arima.predict(len(test_log),return_conf_int=True)
fig,ax = plot_series(np.exp(train_log),colors=[(.4,.4,.4)])
plot_series(np.exp(test_log),ax=ax,colors=[(.4,.4,.9)])

plot_series(np.exp(pred_auto_arima),ax=ax,colors='r')
ax.set_ylabel('Passengers')
ax.set_title('SARIMA Prediction')
conf_int = np.exp(conf_int)
ax.fill_between(test_log.index, conf_int[:,0], conf_int[:,1],alpha=.25,color=[.2,.7,.7])
ax.legend(['Raw Values','Test Values','ARIMA Predictions','95% Confidence Interval'])

plt.show()
# Out:
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
print('p,d,q:',auto_arima.order)
print('P,D,Q,s:',auto_arima.seasonal_order)
# Out:
# p,d,q: (2, 0, 0)
# P,D,Q,s: (0, 1, 1, 12)

# %% [markdown]
# **Conclusions**
# - How does `auto_arima` perform with respect to your previous models ? Can you explain why ?
# <br> Auto-arima is better than my previous models.

# %% [markdown]
# # 4. Cross-Validation

# %% [markdown]
# As you know, cross-validation is a crucial technique in the context of machine learning, designed to assess the predictive performance of these models and mitigate potential pitfalls associated with using limited data. Unlike traditional cross-validation used in other machine learning applications, time series cross-validation takes into account the temporal order of the data, ensuring that does not have any information from the future that it would not otherwise have at the time of making a forecast.
# By dividing the time series data into multiple subsets and iteratively validating the model's performance against unseen data, cross-validation provides valuable insights into how well the ARIMA model generalizes to different time periods. This rigorous evaluation will allow you to fine-tune model hyperparameters (such as ARIMA's parameters), assess forecast accuracy, and build more robust and reliable time series forecasting models.
#
# In the classicial time series literature, time series cross validation is called a **Rolling Forecasting Horizon**. This is explained in details [here](https://robjhyndman.com/hyndsight/tscv/)

# %% [markdown]
# **TODO**
# - Split the train data into a train and validation sets

# %%
# I've written a function to help with the cv of the baseline model
# THIS FUNCTION IS LOCATED IN THE ./forecast DIRECTORY, ALONG WITH THE NOTEBOOK
from forecast.model_selection import time_series_cv
# Reload dataset from pmdarima
from pmdarima.datasets import load_airpassengers
from pmdarima.utils import acf, pacf
from pmdarima import ARIMA
import pandas as pd
# Load dataset
START_DATE = '1949-01-01'
airline = load_airpassengers(as_series=True)

# There's no DateTimeIndex from the bundled dataset. So let's add one.
airline.index = pd.date_range(START_DATE, periods=len(airline), freq='MS')

# Clean & Adjust data
airline_adj = airline / airline.index.days_in_month

# Train / Test split
train, test = ts_train_test_split(airline_adj, '1960-01-01')

# Apply log transformation
train_log = np.log(train).dropna()
test_log = np.log(test).dropna()
# It requires the data to be split into train and validation
train,val = ts_train_test_split(airline_adj, '1960-01-01')

# Apply log transformation
train_log = np.log(train).dropna()
val_log = np.log(val).dropna()
# Print the sizes to see if it's all good
print('Training set size:',train_log.shape)
print('Validation set size:',val_log.shape)
# Out:
# Training set size: (132,)
# Validation set size: (12,)

# %% [markdown]
# ### 4.1 Cross-Validation with Naive model
#
# **TODO**
# - Perform a cross-validation with the Seasonal Naive model you built previously

# %%
from sktime.forecasting.naive import NaiveForecaster
from sktime.forecasting.base import ForecastingHorizon
from sktime.utils.plotting import plot_series

HORIZON = 12  # We plan to make forecasts for the following 12 months
PERIOD = 12  # Expected period of seasonality

# Define the length of time into the future for which forecasts are to be prepared
fh = ForecastingHorizon(val_log.index, is_relative=False)

# %%
# Define the model
naive_model =  NaiveForecaster(strategy='drift',window_length=PERIOD)
HORIZON = 6
# Call time_series_cv
pred_cv_naive = time_series_cv(naive_model, mean_absolute_percentage_error, train_log, val_log, list(range(HORIZON+1)), step=1)
leg = []
# Show results
fig,ax = plt.subplots(figsize=[10,6])
col = sns.color_palette('Oranges', n_colors=len(pred_cv_naive)) 
for i in range(len(pred_cv_naive)):
    ax.plot(pred_cv_naive[i],c=col[i],linewidth=2)
    leg.append(f'Naive Prediction #{i+1}')
ax.set_ylabel('MAPE')
ax.set_title('CV Naive Model Prediction')
# conf_int = np.exp(conf_int)
# ax.fill_between(test_log.index, conf_int[:,0], conf_int[:,1],alpha=.25,color=[.2,.7,.7])
ax.legend(leg)

plt.show()

# %% [markdown]
# ### 4.2 Cross-Validation with ARIMA

# %% [markdown]
# **TODO**
# - Perform a cross-validation with your best ARIMA model.
# - Try different step values in the RollingForecastCV. What's the difference ?
# - In each case, what's the size of the the data the model is trained on ?
# - How many splits did we get ?

# %%
from pmdarima.arima import ARIMA
from pmdarima.model_selection import RollingForecastCV, cross_val_score

# Manually create the arima model
p,d,q = 2, 0, 0
P,D,Q,s = 0, 1, 1, 12
sarm = ARIMA(order=[p,d,q],seasonal_order=[D,P,Q,s])

# Create a RollingForecastCV instance
HORIZON = 6
# Call time_series_cv
pred_cv_arima = time_series_cv(sarm, mean_absolute_percentage_error, train_log, val_log, list(range(HORIZON+1)), step=1)
leg = []
# Show results
fig,ax = plt.subplots(figsize=[10,6])
col = sns.color_palette('Oranges', n_colors=len(pred_cv_arima)) 
for i in range(len(pred_cv_arima)):
    ax.plot(pred_cv_arima[i],c=col[i],linewidth=2)
    leg.append(f'SARIMA Prediction #{i+1}')
ax.set_ylabel('MAPE')
ax.set_title('CV SARIMA Model Prediction')
# conf_int = np.exp(conf_int)
# ax.fill_between(test_log.index, conf_int[:,0], conf_int[:,1],alpha=.25,color=[.2,.7,.7])
ax.legend(leg)

plt.show()

# Call cross_val_score
# Out:
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %% [markdown]
# # 5. The Final Forecast

# %% [markdown]
# **TODO**
# - Following the same methodology as above, produce your final forecast with your best model!
# - Plot the predictions of the **Naive**, **Seasonal Naive**, and your best **SARIMA** model along with the test data, and compare they performances!

# %%
# Your code here
from sktime.utils.plotting import plot_series
from sktime.datasets import load_airline
from sktime.forecasting.naive import NaiveForecaster
from sktime.forecasting.base import ForecastingHorizon

from pmdarima.utils import acf, pacf
from pmdarima import ARIMA

airline = load_airline().dropna()
airline = airline / airline.index.days_in_month
# airline.index = airline.index.to_timestamp()

train, test = ts_train_test_split(airline, '1960-01')
train_log = np.log(train).dropna()
test_log = np.log(test).dropna()
HORIZON = 12  # We plan to make forecasts for the following 12 months
PERIOD = 12  # Expected period of seasonality
fh = ForecastingHorizon(list(range(1, HORIZON+1)), is_relative=True)
fh_12 = fh[:HORIZON]




# Define models
naive_model =  NaiveForecaster(strategy='drift',window_length=PERIOD)
naive_seasonal = NaiveForecaster(strategy='last',sp=PERIOD)
p,d,q = 2, 0, 0
P,D,Q,s = 0, 1, 1, 12
sarm = ARIMA(order=[p,d,q],seasonal_order=[D,P,Q,s])

# Fit models
naive.fit(train_log)
naive_seasonal.fit(train_log)
sarm.fit(train_log)

# Create predictions
pred_naive = naive.predict(fh_12)
pred_naiveseason = naive_seasonal.predict(fh_12)
pred_sarm = sarm.predict(HORIZON)



# Plot predictions
fig,ax = plot_series(np.exp(train_log),colors=[(.4,.4,.4,.4)])
plot_series(np.exp(test_log),ax=ax,colors=[(.9,.4,.9,)])
plot_series(np.exp(pred_naive),ax=ax,colors=[(.9,.4,.4)])
plot_series(np.exp(pred_naiveseason),ax=ax,colors=[(.7,.3,.3)])
plot_series(np.exp(pred_sarm),ax=ax,colors=[(.5,.2,.2)])
ax.set_ylabel('Passengers')
ax.set_title('Final Models Predictions')
# conf_int = np.exp(conf_int)
# ax.fill_between(test_log.index, conf_int[:,0], conf_int[:,1],alpha=.25,color=[.2,.7,.7])
ax.legend(['Raw Values','Test Values','Naive','Naive Seasonal','SARIMA'])

plt.show()
# Out:
# coucou
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %% [markdown]
# # Bonus

# %% [markdown]
# ### B1. Write a class with the following methods:
# * The necessary arguments to split the dataset, fit the auto_arima model etc.
# * A `fit` method which fits the auto_arima naive using a train dataset
# * A `get_metrics` method which computes the MAPE for each models using a test dataset
# * A `predict` method which takes as input a prediction horizon and returns predicted values.
# * A `plot` method which plots the data, and if available the predictions
#
# **Have some time left ?**
# * Add a method `get_cv` Which performs cross validation
# * To further automatize the process, add an automatic detection of the period.
# * Add the possibility to apply a preprocessing of the data before the fit such as a log transformation.

# %%
# Write your class here
class SARIMAX():
    def __init__(self,data,split_date,metric=mean_absolute_percentage_error,horizon=None,period = 12,log_transfo=True):
        self.period = period
        self.data = data
        self.metric = metric
        train, test = ts_train_test_split(data, split_date)
        if log_transfo:
            self.train = np.log(train)
            self.test = np.log(test)
        else:
            self.train = train
            self.test = test
        if horizon== None:
            self.horizon = len(test)
        else:
            self.horizon = horizon
        return
    
    def fit(self):
        self.model  = auto_arima(self.train,seasonal=True,m=self.period,n_jobs=-1) 
        return
    
    def predict(self,horizon):
        return self.model.predict(horizon,return_conf_int=True)
    
    def get_metrics(self):
        predi,conf_int = self.predict(self.horizon)
        return self.metric(self.test.values,predi.values[:len(self.test)])
    
    def plot(self):
        print(self.horizon)
        predi,conf_int = self.predict(self.horizon)
        fig,ax = plot_series(np.exp(self.train),colors=[(.4,.4,.4)])
        plot_series(np.exp(self.test),ax=ax,colors=[(.4,.4,.9)])
        if np.issubdtype(getattr(predi.index, "dtype", np.dtype("O")), np.number):
            predi.index += self.train.index[-1]-predi.index[0]+1
        plot_series(np.exp(predi),ax=ax,colors='r')
        ax.set_ylabel('Passengers')
        ax.set_title('SARIMA Prediction')
        conf_int = np.exp(conf_int)
        ax.fill_between(predi.index, conf_int[:,0], conf_int[:,1],alpha=.25,color=[.2,.7,.7])
        ax.legend(['Raw Values','Test Values','SARIMA Predictions','95% Confidence Interval'])
        plt.show()
        return

# %%
airline = load_airline().dropna()
airline = airline / airline.index.days_in_month
# airline.index = airline.index.to_timestamp()

HORIZON = 12  # We plan to make forecasts for the following 12 months
PERIOD = 12  # Expected period of seasonality
# fh = ForecastingHorizon(list(range(1, HORIZON+1)), is_relative=True)
# fh_12 = fh[:HORIZON]
data = airline
split_date = '1958-01'
srmx = SARIMAX(data,split_date,horizon=72)
srmx.fit()
# Out:
# coucou
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\_validation.py:76: UserWarning: stepwise model cannot be fit in parallel (n_jobs=1). Falling back to stepwise parameter search.
#   warnings.warn('stepwise model cannot be fit in parallel (n_jobs=%i). '
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
srmx.plot()
# Out:
# 72
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
srmx.get_metrics()
# Out:
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 4.398574058192284

# %% [markdown]
# ### B2. Test this method on all the other [11 datasets] of pmdarima
#
# https://alkaline-ml.com/pmdarima/modules/classes.html#module-pmdarima.datasets
# To help you, we provide the list of dataset names and a function to load any of these datasets.
#
# On some of them the method does not work well, why? What could be done to improve it?

# %%
dataset_names = ['airpassengers', 'ausbeer', 'austres', 'gasoline', 'heartrate', 'lynx',  'sunspots', 'taylor', 'wineind', 'woolyrnq'] # 'msft'

def get_ds(ds_name, red_factor=None):
    '''
    Loads a dataset of pmdarima from its ds_name.
    '''
    ds = getattr(pm.datasets, 'load_'+ds_name)(as_series=True).dropna()
    
    if red_factor is not None:
        assert isinstance(red_factor, int)
        ds= ds.groupby(np.arange(ds.index.shape[0])//red_factor).mean()
    
    return ds.dropna()
for dataset in dataset_names[1:]:
    print(dataset)
    ds = get_ds(dataset)
    split_date = str(ds.index[-12])
    srmx = SARIMAX(ds,split_date,horizon=72)
    srmx.fit()
    srmx.plot()
# Out:
# ausbeer
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\_validation.py:76: UserWarning: stepwise model cannot be fit in parallel (n_jobs=1). Falling back to stepwise parameter search.
#   warnings.warn('stepwise model cannot be fit in parallel (n_jobs=%i). '
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 72
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# austres
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\_validation.py:76: UserWarning: stepwise model cannot be fit in parallel (n_jobs=1). Falling back to stepwise parameter search.
#   warnings.warn('stepwise model cannot be fit in parallel (n_jobs=%i). '
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 72
# gasoline
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\_validation.py:76: UserWarning: stepwise model cannot be fit in parallel (n_jobs=1). Falling back to stepwise parameter search.
#   warnings.warn('stepwise model cannot be fit in parallel (n_jobs=%i). '
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 72
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# heartrate
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\_validation.py:76: UserWarning: stepwise model cannot be fit in parallel (n_jobs=1). Falling back to stepwise parameter search.
#   warnings.warn('stepwise model cannot be fit in parallel (n_jobs=%i). '
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 72
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\pmdarima\arima\_validation.py:76: UserWarning: stepwise model cannot be fit in parallel (n_jobs=1). Falling back to stepwise parameter search.
#   warnings.warn('stepwise model cannot be fit in parallel (n_jobs=%i). '
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# lynx
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 72
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\mehdi\anaconda3\envs\ML6\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# sunspots
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 18
#      16 ds = get_ds(dataset)
#      17 split_date = str(ds.index[-12])
# ---> 18 srmx = SARIMAX(ds,split_date,horizon=72)
#      19 srmx.fit()
#      20 srmx.plot()
#
# Cell In[152], line 7, in SARIMAX.__init__(self, data, split_date, metric, horizon, period, log_transfo)
#       5 self.data = data
#       6 self.metric = metric
# ----> 7 train, test = ts_train_test_split(data, split_date)
#       8 if log_transfo:
#       9     self.train = np.log(train)
#
# Cell In[150], line 24, in ts_train_test_split(data, split_date)
#      22 # Case 1: numeric index
#      23 if np.issubdtype(getattr(idx, "dtype", np.dtype("O")), np.number) or isinstance(idx, pd.Index):
# ---> 24     pos_split = int(split_date)
#      25     pos_split=np.argwhere(idx>pos_split)[0][0]
#      26     train = data.iloc[:pos_split]
#
# ValueError: invalid literal for int() with base 10: 'Jan 1983'

# %%
ds.index
# Out:
# Index(['Jan 1749', 'Feb 1749', 'Mar 1749', 'Apr 1749', 'May 1749', 'Jun 1749',
#        'Jul 1749', 'Aug 1749', 'Sep 1749', 'Oct 1749',
#        ...
#        'Mar 1983', 'Apr 1983', 'May 1983', 'Jun 1983', 'Jul 1983', 'Aug 1983',
#        'Sep 1983', 'Oct 1983', 'Nov 1983', 'Dec 1983'],
#       dtype='object', length=2820)

# %% [markdown]
# ### B3. Want some more ?
#
# Choose your poison: https://data.world/datasets/time-series
